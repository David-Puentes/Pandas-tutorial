# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
location= r"C:\Users\TOSHIBA-PC\Downloads\311-service-requests.csv"
df=pd.read_csv(location,sep=",")
df.head()
# Out:
# C:\Users\TOSHIBA-PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# ...

# %%
df["Agency"] # Llamar por columnas
df.iloc[:3]  # Llamar por filas
df["Agency Name"][5] # Llamar por fila y columna
# Out:
# 'New York City Police Department'

# %%
df[["Agency","Descriptor","Location Type"]] # Llamar múltiples columnas
df[["Agency","Descriptor","Location Type"]][:5] # Llamar múltiples columnas y fila
# Out:
#   Agency                    Descriptor        Location Type
# 0   NYPD                  Loud Talking      Street/Sidewalk
# 1   NYPD  Commercial Overnight Parking      Street/Sidewalk
# 2   NYPD              Loud Music/Party  Club/Bar/Restaurant
# 3   NYPD                Car/Truck Horn      Street/Sidewalk
# 4  DOHMH  Condition Attracting Rodents           Vacant Lot

# %%
complaint_counts=df["Complaint Type"].value_counts() # Valores más frecuentes
complaint_counts[:10].plot.bar()
plt.show()

# %%
# Seleccionar las llamadas por "Noise-Street/Sidewalk"
mask=df["Complaint Type"]=="Noise - Street/Sidewalk"
mask_2=df["Borough"]=="BROOKLYN" 
df[mask & mask_2] # Seleccionar por más de un criterio (Tipo de queja) y Brooklyn
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 31        26595564  10/31/2013 12:30:36 AM                     NaN   NYPD
# 49        26595553  10/31/2013 12:05:10 AM  10/31/2013 02:43:43 AM   NYPD
# 109       26594653  10/30/2013 11:26:32 PM  10/31/2013 12:18:54 AM   NYPD
# 236       26591992  10/30/2013 10:02:58 PM  10/30/2013 10:23:20 PM   NYPD
# 370       26594167  10/30/2013 08:38:25 PM  10/30/2013 10:26:28 PM   NYPD
# 378       26590110  10/30/2013 08:32:13 PM  10/30/2013 11:58:00 PM   NYPD
# 656       26595791  10/30/2013 06:07:39 PM  10/30/2013 06:23:54 PM   NYPD
# 1251      26593754  10/30/2013 03:04:51 PM  10/30/2013 11:39:21 PM   NYPD
# 5416      26582351  10/29/2013 10:07:02 PM  10/29/2013 10:33:37 PM   NYPD
# 5584      26585573  10/29/2013 08:15:59 PM  10/29/2013 10:57:37 PM   NYPD
# 5991      26586468  10/29/2013 04:53:21 PM  10/29/2013 11:36:00 PM   NYPD
# 6000      26582848  10/29/2013 04:51:10 PM  10/29/2013 11:04:51 PM   NYPD
# ...

# %%
noise=df[mask]
noise_complaints=noise["Borough"].value_counts() # Localidades más ruidosas

# %%
complaints=df["Borough"].value_counts()
(noise_complaints/complaints).plot.bar()
plt.show()
